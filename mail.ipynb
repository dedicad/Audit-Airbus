# %%
email = ""

# %%
import email
import base64

path = './mission.eml'

msg = email.message_from_file(open(path))
attachments=msg.get_payload()

# base64.b64decode(text)
test = msg.get("body")
print (test)
# Out:
# None

# %%
print (attachments)
# Out:
# [<email.message.Message object at 0x7fb446234be0>, <email.message.Message object at 0x7fb4462347f0>]

# %%
import email
import zipfile
import io
import base64

for part in msg.walk():
    print ("part :",part,"\n\n\n")
    # You might also check to see if the content-type for your zip files is
    # application/zip instead of application/octet-stream
#     if part.get_content_type() == 'application/zip':
#         zip_bytes = base64.b64decode(part.get_payload())
#         file_wrapper = io.StringIO(zip_bytes)
#         if zipfile.is_zipfile(file_wrapper):
#             with zipfile.ZipFile(file_wrapper, 'r') as zf:
#                 zf.extractall()
# Out:
# part : MIME-Version: 1.0
# Received: from FR0-03TMRG03-P04.central.mail.corp (172.16.65.26) by
#  FR0-03TMRG03-P03.central.mail.corp (172.16.64.26) with Microsoft SMTP Server
#  (TLS) id 15.0.1473.3 via Mailbox Transport; Tue, 23 Apr 2019 08:51:38 +0200
# Received: from BIGCORPLABS.COM (41.27.15.13) by FR0-03TMRG03-P03.central.mail.corp
#  (172.16.64.26) with Microsoft SMTP Server id 15.0.1365.1; Tue, 23 Apr 2019
#  08:51:34 +0200
# From: "general.services@BIGCORPLABS.COM" <@BIGCORPLABS.COM>
# To: "Martin, Simon" <simon.martin.external@BIGCORPLABS.com>
# Subject: WTJoaGJHeGxibWRsSUdseklHTnZiV2x1Wnc9PQo=
# Thread-Topic: WTJoaGJHeGxibWRsSUdseklHTnZiV2x1Wnc9PQo=
# Date: Tue, 23 Apr 2019 08:38:49 +0200
# Message-ID: <ADR44000002458885001FC15B42566501EE999B28762228B25DC@BIGCORPLABS.COM>
# Content-Language: en-US
# X-MS-Exchange-Organization-AuthAs: Anonymous
# X-MS-Exchange-Organization-AuthSource: FR0-03TMRG03-P03.central.mail.corp
# X-MS-Has-Attach: yes
# ...
